# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import pandas as pd
from pandas import DataFrame
import datetime
import urllib

# %%
from math import radians, cos, sin, asin, sqrt
 
def haversine(df): # 经度1，纬度1，经度2，纬度2 （十进制度数）
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    s = []
    for i in range(len(df)):
        a7_lng = 121.3852857
        a7_lat = 25.0442435
        # 将十进制度数转化为弧度
        lon1, lat1, lon2, lat2 = map(radians, [df.iloc[i]['lng'], df.iloc[i]['lat'], a7_lng, a7_lat])
        # haversine公式
        dlon = lon2 - lon1 
        dlat = lat2 - lat1 
        a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
        c = 2 * asin(sqrt(a)) 
        r = 6371 # 地球平均半径，单位为公里
        s.append(c * r)
    df['distance'] = s
    return df

# %%
a7_lng = 121.3852857
a7_lat = 25.0442435

# %%
clinic = pd.read_csv('C:\\Users\\Double 8\\A7_data\\clinic.csv')
viewpoint = pd.read_csv('C:\\Users\\Double 8\\A7_data\\viewpoint.csv')
job = pd.read_csv('C:\\Users\\Double 8\\A7_data\\job.csv')

# %%
job
# Out:
#               company_name   company_address
# 0          廣達集團_雲達科技股份有限公司  桃園市龜山區文化二路211號1樓
# 1      GARMIN_台灣國際航電股份有限公司    桃園市龜山區華亞二路270號
# 2               啟裕國際股份有限公司   桃園市龜山區龜山鄉興業街13號
# 3      GARMIN_台灣國際航電股份有限公司    桃園市龜山區華亞二路270號
# 4          廣達集團_雲達科技股份有限公司  桃園市龜山區文化二路211號1樓
# 5                 倉和股份有限公司  桃園市龜山區自強北路17巷31號
# 6      GARMIN_台灣國際航電股份有限公司    桃園市龜山區華亞二路270號
# 7             元太科技工業股份有限公司    桃園市龜山區華亞二路199號
# 8               飛捷科技股份有限公司     桃園市龜山區華亞三路36號
# 9                 登威股份有限公司      桃園市龜山區頂湖九街8號
# 10  新加坡商圖傑億科半導體股份有限公司台灣分公司            桃園市龜山區
# 11     GARMIN_台灣國際航電股份有限公司    桃園市龜山區華亞二路270號
# 12              啟裕國際股份有限公司      桃園市龜山區興業街13號
# 13     GARMIN_台灣國際航電股份有限公司    桃園市龜山區華亞二路270號
# 14     GARMIN_台灣國際航電股份有限公司    桃園市龜山區華亞二路270號
# 15              有量科技股份有限公司       桃園市龜山區茶專路6號
# 16                  恆美牙醫診所     桃園市龜山區文青路207號
# 17              台灣椿本股份有限公司  桃園市龜山區自強北路17巷33號
# 18              晶碩光學股份有限公司   桃園市龜山區興業街五號二樓之一
# 19     GARMIN_台灣國際航電股份有限公司    桃園市龜山區華亞二路270號

# %%
import requests
import urllib.parse as urllib
import urllib.request as urllib2
import json
import time
import pandas as pd
import numpy as np
import requests
import time
from bs4 import BeautifulSoup

def get_latitude_longtitude(dataframe):
    # decode url
    latt = []
    lngg = []
    for i in range(len(dataframe)):        
        address = urllib.quote(dataframe['company_address'].iloc[i])
        url = "https://maps.googleapis.com/maps/api/geocode/json?address=" + address + '&key=' + 'AIzaSyAwXudhof89ppEce5Vj7Y3xh5lYQUFjs5Y'

        while True:
            res = requests.get(url)
            js = json.loads(res.text)

            if js["status"] != "OVER_QUERY_LIMIT":
                time.sleep(1.5)
                break
        result = js["results"][0]["geometry"]["location"]
        print(result)
        lat = result["lat"]
        lng = result["lng"]
        latt.append(lat)
        lngg.append(lng)
    dataframe['lat'] = latt
    dataframe['lng'] = lngg
    return dataframe

# %%
jobb = get_latitude_longtitude(job)
# Out:
# {'lat': 25.0511193, 'lng': 121.373196}
# {'lat': 25.0430173, 'lng': 121.3736891}
# {'lat': 24.9892082, 'lng': 121.3272098}
# {'lat': 25.0430173, 'lng': 121.3736891}
# {'lat': 25.0511193, 'lng': 121.373196}
# {'lat': 25.0004986, 'lng': 121.3447405}
# {'lat': 25.0430173, 'lng': 121.3736891}
# {'lat': 25.0440702, 'lng': 121.372722}
# {'lat': 25.0487861, 'lng': 121.3799168}
# {'lat': 25.0377576, 'lng': 121.3664881}
# {'lat': 25.0199092, 'lng': 121.3655989}
# {'lat': 25.0430173, 'lng': 121.3736891}
# {'lat': 24.9892082, 'lng': 121.3272098}
# {'lat': 25.0430173, 'lng': 121.3736891}
# {'lat': 25.0430173, 'lng': 121.3736891}
# {'lat': 25.0004031, 'lng': 121.355084}
# {'lat': 25.0403065, 'lng': 121.3887956}
# {'lat': 25.0006207, 'lng': 121.3448302}
# {'lat': 24.988139, 'lng': 121.328487}
# {'lat': 25.0430173, 'lng': 121.3736891}

# %%
dis_clinic = haversine(clinic)
dis_viewpoint = haversine(viewpoint)

# %%
dis_job = haversine(job)

# %%
dis_clinic
# Out:
#          clinic_address        lat         lng  distance
# 0          桃園市龜山區文興路99號  25.058454  121.364686  2.608231
# 1       桃園市龜山區文化二路38之3號  25.057877  121.366025  2.462179
# 2          桃園市龜山區文興路95號  25.058552  121.364583  2.623040
# 3     桃園市龜山區中興路一段372之3號  24.995005  121.340136  7.118475
# 4        桃園市龜山區自強南路698號  24.991462  121.333836  7.830834
# 5          桃園市龜山區南祥路55號  25.046672  121.297448  8.852846
# 6       桃園市龜山區萬壽路一段331號  25.017001  121.402224  3.476922
# 7        桃園市龜山區中和南路111號  24.994209  121.337537  7.355333
# 8          桃園市龜山區南祥路50號  25.046446  121.297641  8.832688
# 9      桃園市龜山區復興一路30巷40號  25.059569  121.370381  2.271169
# 10     桃園市龜山區萬壽路二段1102號  24.994164  121.334220  7.581859
